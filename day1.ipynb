# %%
import os
import cv2

# %%
image_path = os.path.join('.', 'assets', "image1.jpg")
img = cv2.imread(image_path)

# %%
cv2.imwrite(os.path.join('.', 'assets', "image1_out.jpg"), img)
cv2.imshow('img', img)
cv2.waitKey(0)
# Out:
# 2026-06-30 16:25:16.195 python[85392:2958702] +[IMKClient subclass]: chose IMKClient_Modern
# 2026-06-30 16:25:16.195 python[85392:2958702] +[IMKInputSession subclass]: chose IMKInputSession_Modern
